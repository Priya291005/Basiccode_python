# %%
n=input()
c=str(n)
s=c[::-1]
if s==n:
    print("Yes")
else:
    print("No")
# Out:
#  mam
# Yes

# %%
n=int(input())
s=list(map(int,input().split()))
p=s.sort()
c=str(p)
d=c[::-1]
print(d)
# Out:
#  2
#  1 2
# enoN

# %%
n=int(input())
for i in range(1,n+1):
    for j in range(i):
        print("*",end)
# Out:
#  3
# * * * * * *
